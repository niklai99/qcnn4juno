# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as tk

from keras.layers import Dense, Dropout, Flatten, Conv2D, Input, Add, \
                         Activation, ZeroPadding2D, BatchNormalization, \
                         AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model
from keras.initializers import glorot_uniform

# %% [markdown]
# Primo blocco conv, NON è un residual block!\
# Output del layer shape = ??

# %%
def conv1(X, filters = 32 , block="conv1", stage=2):
            
        # defining name basis
        conv_name_base = 'res' + str(stage) + block + '_branch'
        bn_name_base = 'bn' + str(stage) + block + '_branch'
        
        X_input = X
        # First component of main path
        X = Conv2D(filters, kernel_size = (6,3), strides = (2,1),
                name = conv_name_base + '2a',
                #nchannels??
                # data_format="channels_first", 
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)
        X = BatchNormalization(axis = 1, name = bn_name_base + '2a')(X)
        X = Activation('relu')(X)
        
        # Second component of main path
        X = Conv2D(filters, kernel_size = (3,3), strides = (2,2),
                name = conv_name_base + '2b',
                #nchannels?? 
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)
        X = BatchNormalization(axis=1, name = bn_name_base + '2b')(X)
        X = Activation('relu')(X)

        X = MaxPooling2D((3,3), strides=(1, 1))(X)
        
        return X

# %%
# X_input = Input(shape=(219,122,2)) 

# res1 = conv1(X_input)
# res1.summary()

# %% [markdown]
# Secondo blocco conv: Residual block!

# %%
def conv2x(X, stride, filters, block,stage=2):
        # defining name basis
        conv_name_base = 'res' + str(stage) + block + '_branch'
        bn_name_base = 'bn' + str(stage) + block + '_branch'

        #filters for each ==> there are two filters because 4 layer 
        #                     --> the first 2 and the last 2 have the same f 
        f1,f2 = filters
        s = stride
        #skip path for the residual part
        X_shortcut = Conv2D(f2, kernel_size = (3,3), strides = (s,s),
                name = conv_name_base + '2',
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)

        X_shortcut = BatchNormalization(axis=1, name = bn_name_base + '2')(X_shortcut)

        # First component of main path
        X = Conv2D(f1, kernel_size = (1,1), strides = (1,1),
                name = conv_name_base + '2a',
                #nchannels?? 
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)
        X = BatchNormalization(axis = 1, name = bn_name_base + '2a')(X)
        X = Activation('relu')(X)

        # Second component of main path
        X = Conv2D(f1, kernel_size = (3,3), strides = (s,s),
                name = conv_name_base + '2b',
                #nchannels?? 
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)
        X = BatchNormalization(axis=1, name = bn_name_base + '2b')(X)
        X = Activation('relu')(X)
        
        # Second component of main path
        X = Conv2D(f2, kernel_size = (1,1), strides = (1,1),
                name = conv_name_base + '2c',
                #nchannels?? 
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)
        X = BatchNormalization(axis=1, name = bn_name_base + '2c')(X)
        X = Activation('relu')(X)

        X = Add()([X, X_shortcut])
        out = Activation('relu')(X)

        return out

# %%
# X_input = Input(shape=( 24, 26, 256)) 

# res2 = conv2x(X_input, stride=2, filters=[128,512], block="a")
# res2.summary()

# %%
def ResNetJ(feature, lr_power=-3.0, lr_decay=0.0):
    """
    Implementation of the popular ResNet50 the following architecture:
    Arguments:
        feature is a string which allow two input values:
        --> 'vertex' or 'energy'
    """
    
    # Define the input as a tensor with shape input_shape
    # X_input = Input(shape=(230,124,2))
    X_input = Input(shape=(219,122,2))
    
    # Stage 1
    X = conv1(X_input, block="conv1")
    # Stage2
    X = conv2x(X, stride=1, filters=[32,128], block="conv2x_1")
    X = conv2x(X, stride=1, filters=[32,128], block="conv2x_2")
    X = conv2x(X, stride=1, filters=[32,128], block="conv2x_3")

    # Stage 3
    # X = conv2x(X, stride=2, filters=[64,256], block="conv3x_1")
    X = conv2x(X, stride=1, filters=[64,256], block="conv3x_2")
    X = conv2x(X, stride=1, filters=[64,256], block="conv3x_3")
    X = conv2x(X, stride=1, filters=[64,256], block="conv3x_4")

    # Stage 4 
    # X = conv2x(X, stride=2, filters=[128,512], block="conv4x_1")
    X = conv2x(X, stride=1, filters=[128,512], block="conv4x_2")
    X = conv2x(X, stride=1, filters=[128,512], block="conv4x_3")
    X = conv2x(X, stride=1, filters=[128,512], block="conv4x_4")
    X = conv2x(X, stride=1, filters=[128,512], block="conv4x_5")
    X = conv2x(X, stride=1, filters=[128,512], block="conv4x_6")

    # Stage 5
    X = conv2x(X, stride=2, filters=[256,1024], block="conv5x_1")
    X = conv2x(X, stride=1, filters=[256,1024], block="conv5x_2")
    X = conv2x(X, stride=1, filters=[256,1024], block="conv5x_3")

    """
    prova con i filters originali del papaer ma senza i blocchi rossi
    """
    # Stage 1
    # X = conv1(X_input, block="conv1")
    # # Stage2
    # X = conv2x(X, stride=1, filters=[64,256], block="conv2x_1")
    # # X = conv2x(X, stride=1, filters=[64,256], block="conv2x_2")
    # # X = conv2x(X, stride=1, filters=[64,256], block="conv2x_3")

    # # Stage 3
    # X = conv2x(X, stride=2, filters=[64,256], block="conv3x_1")
    # X = conv2x(X, stride=1, filters=[128,512], block="conv3x_2")
    # # X = conv2x(X, stride=1, filters=[128,512], block="conv3x_3")
    # # X = conv2x(X, stride=1, filters=[128,512], block="conv3x_4")

    # # Stage 4 
    # X = conv2x(X, stride=2, filters=[128,512], block="conv4x_1")
    # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_2")
    # # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_3")
    # # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_4")
    # # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_5")
    # # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_6")

    # # Stage 5
    # X = conv2x(X, stride=2, filters=[512,2048], block="conv5x_1")
    # X = conv2x(X, stride=1, filters=[512,2048], block="conv5x_2")
    # # X = conv2x(X, stride=1, filters=[512,2048], block="conv5x_3")

    # AVGPOOL 
    X = AveragePooling2D((2,2), name='avg_pool')(X)
    # Flatten
    X = Flatten()(X)
    X = Dense(512, name='first_dense',  kernel_initializer=glorot_uniform(seed=0))(X)
    X = Dense(100, name='second_dense', kernel_initializer=glorot_uniform(seed=0))(X)

    # Output 
    if(feature=="energy"):
        X = Dense(1, name='fc_outputs', kernel_initializer=glorot_uniform(seed=0))(X)
    elif(feature=="vertex"):
        X = Dense(3, name='fc_outputs', kernel_initializer=glorot_uniform(seed=0))(X)
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name = 'ResNetJ')
    
    # Compile model
    learning_rate = 10.0**(lr_power)
    opt = tk.optimizers.Adam(learning_rate=learning_rate, beta_1 = 0.9, beta_2 = 0.999 )

    model.compile(loss="mean_squared_error", optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
res = ResNetJ(feature="energy")
res.summary()
# Out:
# Model: "ResNetJ"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_34 (InputLayer)          [(None, 219, 122, 2  0           []
#                                 )]
#
#  res2conv1_branch2a (Conv2D)    (None, 107, 120, 32  1184        ['input_34[0][0]']
#                                 )
#
#  bn2conv1_branch2a (BatchNormal  (None, 107, 120, 32  428        ['res2conv1_branch2a[0][0]']
#  ization)                       )
#
#  activation_1166 (Activation)   (None, 107, 120, 32  0           ['bn2conv1_branch2a[0][0]']
#                                 )
#
#  res2conv1_branch2b (Conv2D)    (None, 53, 59, 32)   9248        ['activation_1166[0][0]']
#
#  bn2conv1_branch2b (BatchNormal  (None, 53, 59, 32)  212         ['res2conv1_branch2b[0][0]']
#  ization)
#
#  activation_1167 (Activation)   (None, 53, 59, 32)   0           ['bn2conv1_branch2b[0][0]']
#
#  max_pooling2d_33 (MaxPooling2D  (None, 51, 57, 32)  0           ['activation_1167[0][0]']
#  )
#
#  res2conv2x_1_branch2a (Conv2D)  (None, 51, 57, 32)  1056        ['max_pooling2d_33[0][0]']
#
#  bn2conv2x_1_branch2a (BatchNor  (None, 51, 57, 32)  204         ['res2conv2x_1_branch2a[0][0]']
#  malization)
#
#  activation_1168 (Activation)   (None, 51, 57, 32)   0           ['bn2conv2x_1_branch2a[0][0]']
#
#  res2conv2x_1_branch2b (Conv2D)  (None, 49, 55, 32)  9248        ['activation_1168[0][0]']
#
#  bn2conv2x_1_branch2b (BatchNor  (None, 49, 55, 32)  196         ['res2conv2x_1_branch2b[0][0]']
#  malization)
#
#  activation_1169 (Activation)   (None, 49, 55, 32)   0           ['bn2conv2x_1_branch2b[0][0]']
#
#  res2conv2x_1_branch2c (Conv2D)  (None, 49, 55, 128)  4224       ['activation_1169[0][0]']
#
#  bn2conv2x_1_branch2c (BatchNor  (None, 49, 55, 128)  196        ['res2conv2x_1_branch2c[0][0]']
#  malization)
#
#  res2conv2x_1_branch2 (Conv2D)  (None, 49, 55, 128)  36992       ['max_pooling2d_33[0][0]']
#
#  activation_1170 (Activation)   (None, 49, 55, 128)  0           ['bn2conv2x_1_branch2c[0][0]']
#
#  bn2conv2x_1_branch2 (BatchNorm  (None, 49, 55, 128)  196        ['res2conv2x_1_branch2[0][0]']
#  alization)
#
#  add_275 (Add)                  (None, 49, 55, 128)  0           ['activation_1170[0][0]',
#                                                                   'bn2conv2x_1_branch2[0][0]']
#
#  activation_1171 (Activation)   (None, 49, 55, 128)  0           ['add_275[0][0]']
#
#  res2conv2x_2_branch2a (Conv2D)  (None, 49, 55, 32)  4128        ['activation_1171[0][0]']
#
#  bn2conv2x_2_branch2a (BatchNor  (None, 49, 55, 32)  196         ['res2conv2x_2_branch2a[0][0]']
#  malization)
#
#  activation_1172 (Activation)   (None, 49, 55, 32)   0           ['bn2conv2x_2_branch2a[0][0]']
#
#  res2conv2x_2_branch2b (Conv2D)  (None, 47, 53, 32)  9248        ['activation_1172[0][0]']
#
#  bn2conv2x_2_branch2b (BatchNor  (None, 47, 53, 32)  188         ['res2conv2x_2_branch2b[0][0]']
#  malization)
#
#  activation_1173 (Activation)   (None, 47, 53, 32)   0           ['bn2conv2x_2_branch2b[0][0]']
#
#  res2conv2x_2_branch2c (Conv2D)  (None, 47, 53, 128)  4224       ['activation_1173[0][0]']
#
#  bn2conv2x_2_branch2c (BatchNor  (None, 47, 53, 128)  188        ['res2conv2x_2_branch2c[0][0]']
#  malization)
#
#  res2conv2x_2_branch2 (Conv2D)  (None, 47, 53, 128)  147584      ['activation_1171[0][0]']
#
#  activation_1174 (Activation)   (None, 47, 53, 128)  0           ['bn2conv2x_2_branch2c[0][0]']
#
#  bn2conv2x_2_branch2 (BatchNorm  (None, 47, 53, 128)  188        ['res2conv2x_2_branch2[0][0]']
#  alization)
#
#  add_276 (Add)                  (None, 47, 53, 128)  0           ['activation_1174[0][0]',
#                                                                   'bn2conv2x_2_branch2[0][0]']
#
#  activation_1175 (Activation)   (None, 47, 53, 128)  0           ['add_276[0][0]']
#
#  res2conv2x_3_branch2a (Conv2D)  (None, 47, 53, 32)  4128        ['activation_1175[0][0]']
#
#  bn2conv2x_3_branch2a (BatchNor  (None, 47, 53, 32)  188         ['res2conv2x_3_branch2a[0][0]']
#  malization)
#
#  activation_1176 (Activation)   (None, 47, 53, 32)   0           ['bn2conv2x_3_branch2a[0][0]']
#
#  res2conv2x_3_branch2b (Conv2D)  (None, 45, 51, 32)  9248        ['activation_1176[0][0]']
#
#  bn2conv2x_3_branch2b (BatchNor  (None, 45, 51, 32)  180         ['res2conv2x_3_branch2b[0][0]']
#  malization)
#
#  activation_1177 (Activation)   (None, 45, 51, 32)   0           ['bn2conv2x_3_branch2b[0][0]']
#
#  res2conv2x_3_branch2c (Conv2D)  (None, 45, 51, 128)  4224       ['activation_1177[0][0]']
#
#  bn2conv2x_3_branch2c (BatchNor  (None, 45, 51, 128)  180        ['res2conv2x_3_branch2c[0][0]']
#  malization)
#
#  res2conv2x_3_branch2 (Conv2D)  (None, 45, 51, 128)  147584      ['activation_1175[0][0]']
#
#  activation_1178 (Activation)   (None, 45, 51, 128)  0           ['bn2conv2x_3_branch2c[0][0]']
#
#  bn2conv2x_3_branch2 (BatchNorm  (None, 45, 51, 128)  180        ['res2conv2x_3_branch2[0][0]']
#  alization)
#
#  add_277 (Add)                  (None, 45, 51, 128)  0           ['activation_1178[0][0]',
#                                                                   'bn2conv2x_3_branch2[0][0]']
#
#  activation_1179 (Activation)   (None, 45, 51, 128)  0           ['add_277[0][0]']
#
#  res2conv3x_2_branch2a (Conv2D)  (None, 45, 51, 64)  8256        ['activation_1179[0][0]']
#
#  bn2conv3x_2_branch2a (BatchNor  (None, 45, 51, 64)  180         ['res2conv3x_2_branch2a[0][0]']
#  malization)
#
#  activation_1180 (Activation)   (None, 45, 51, 64)   0           ['bn2conv3x_2_branch2a[0][0]']
#
#  res2conv3x_2_branch2b (Conv2D)  (None, 43, 49, 64)  36928       ['activation_1180[0][0]']
#
#  bn2conv3x_2_branch2b (BatchNor  (None, 43, 49, 64)  172         ['res2conv3x_2_branch2b[0][0]']
#  malization)
#
#  activation_1181 (Activation)   (None, 43, 49, 64)   0           ['bn2conv3x_2_branch2b[0][0]']
#
#  res2conv3x_2_branch2c (Conv2D)  (None, 43, 49, 256)  16640      ['activation_1181[0][0]']
#
#  bn2conv3x_2_branch2c (BatchNor  (None, 43, 49, 256)  172        ['res2conv3x_2_branch2c[0][0]']
#  malization)
#
#  res2conv3x_2_branch2 (Conv2D)  (None, 43, 49, 256)  295168      ['activation_1179[0][0]']
#
#  activation_1182 (Activation)   (None, 43, 49, 256)  0           ['bn2conv3x_2_branch2c[0][0]']
#
#  bn2conv3x_2_branch2 (BatchNorm  (None, 43, 49, 256)  172        ['res2conv3x_2_branch2[0][0]']
#  alization)
#
#  add_278 (Add)                  (None, 43, 49, 256)  0           ['activation_1182[0][0]',
#                                                                   'bn2conv3x_2_branch2[0][0]']
#
#  activation_1183 (Activation)   (None, 43, 49, 256)  0           ['add_278[0][0]']
#
#  res2conv3x_3_branch2a (Conv2D)  (None, 43, 49, 64)  16448       ['activation_1183[0][0]']
#
#  bn2conv3x_3_branch2a (BatchNor  (None, 43, 49, 64)  172         ['res2conv3x_3_branch2a[0][0]']
#  malization)
#
#  activation_1184 (Activation)   (None, 43, 49, 64)   0           ['bn2conv3x_3_branch2a[0][0]']
#
#  res2conv3x_3_branch2b (Conv2D)  (None, 41, 47, 64)  36928       ['activation_1184[0][0]']
#
#  bn2conv3x_3_branch2b (BatchNor  (None, 41, 47, 64)  164         ['res2conv3x_3_branch2b[0][0]']
#  malization)
#
#  activation_1185 (Activation)   (None, 41, 47, 64)   0           ['bn2conv3x_3_branch2b[0][0]']
#
#  res2conv3x_3_branch2c (Conv2D)  (None, 41, 47, 256)  16640      ['activation_1185[0][0]']
#
#  bn2conv3x_3_branch2c (BatchNor  (None, 41, 47, 256)  164        ['res2conv3x_3_branch2c[0][0]']
#  malization)
#
#  res2conv3x_3_branch2 (Conv2D)  (None, 41, 47, 256)  590080      ['activation_1183[0][0]']
#
#  activation_1186 (Activation)   (None, 41, 47, 256)  0           ['bn2conv3x_3_branch2c[0][0]']
#
#  bn2conv3x_3_branch2 (BatchNorm  (None, 41, 47, 256)  164        ['res2conv3x_3_branch2[0][0]']
#  alization)
#
#  add_279 (Add)                  (None, 41, 47, 256)  0           ['activation_1186[0][0]',
#                                                                   'bn2conv3x_3_branch2[0][0]']
#
#  activation_1187 (Activation)   (None, 41, 47, 256)  0           ['add_279[0][0]']
#
#  res2conv3x_4_branch2a (Conv2D)  (None, 41, 47, 64)  16448       ['activation_1187[0][0]']
#
#  bn2conv3x_4_branch2a (BatchNor  (None, 41, 47, 64)  164         ['res2conv3x_4_branch2a[0][0]']
#  malization)
#
#  activation_1188 (Activation)   (None, 41, 47, 64)   0           ['bn2conv3x_4_branch2a[0][0]']
#
#  res2conv3x_4_branch2b (Conv2D)  (None, 39, 45, 64)  36928       ['activation_1188[0][0]']
#
#  bn2conv3x_4_branch2b (BatchNor  (None, 39, 45, 64)  156         ['res2conv3x_4_branch2b[0][0]']
#  malization)
#
#  activation_1189 (Activation)   (None, 39, 45, 64)   0           ['bn2conv3x_4_branch2b[0][0]']
#
#  res2conv3x_4_branch2c (Conv2D)  (None, 39, 45, 256)  16640      ['activation_1189[0][0]']
#
#  bn2conv3x_4_branch2c (BatchNor  (None, 39, 45, 256)  156        ['res2conv3x_4_branch2c[0][0]']
#  malization)
#
#  res2conv3x_4_branch2 (Conv2D)  (None, 39, 45, 256)  590080      ['activation_1187[0][0]']
#
#  activation_1190 (Activation)   (None, 39, 45, 256)  0           ['bn2conv3x_4_branch2c[0][0]']
#
#  bn2conv3x_4_branch2 (BatchNorm  (None, 39, 45, 256)  156        ['res2conv3x_4_branch2[0][0]']
#  alization)
#
#  add_280 (Add)                  (None, 39, 45, 256)  0           ['activation_1190[0][0]',
#                                                                   'bn2conv3x_4_branch2[0][0]']
#
#  activation_1191 (Activation)   (None, 39, 45, 256)  0           ['add_280[0][0]']
#
#  res2conv4x_2_branch2a (Conv2D)  (None, 39, 45, 128)  32896      ['activation_1191[0][0]']
#
#  bn2conv4x_2_branch2a (BatchNor  (None, 39, 45, 128)  156        ['res2conv4x_2_branch2a[0][0]']
#  malization)
#
#  activation_1192 (Activation)   (None, 39, 45, 128)  0           ['bn2conv4x_2_branch2a[0][0]']
#
#  res2conv4x_2_branch2b (Conv2D)  (None, 37, 43, 128)  147584     ['activation_1192[0][0]']
#
#  bn2conv4x_2_branch2b (BatchNor  (None, 37, 43, 128)  148        ['res2conv4x_2_branch2b[0][0]']
#  malization)
#
#  activation_1193 (Activation)   (None, 37, 43, 128)  0           ['bn2conv4x_2_branch2b[0][0]']
#
#  res2conv4x_2_branch2c (Conv2D)  (None, 37, 43, 512)  66048      ['activation_1193[0][0]']
#
#  bn2conv4x_2_branch2c (BatchNor  (None, 37, 43, 512)  148        ['res2conv4x_2_branch2c[0][0]']
#  malization)
#
#  res2conv4x_2_branch2 (Conv2D)  (None, 37, 43, 512)  1180160     ['activation_1191[0][0]']
#
#  activation_1194 (Activation)   (None, 37, 43, 512)  0           ['bn2conv4x_2_branch2c[0][0]']
#
#  bn2conv4x_2_branch2 (BatchNorm  (None, 37, 43, 512)  148        ['res2conv4x_2_branch2[0][0]']
#  alization)
#
#  add_281 (Add)                  (None, 37, 43, 512)  0           ['activation_1194[0][0]',
#                                                                   'bn2conv4x_2_branch2[0][0]']
#
#  activation_1195 (Activation)   (None, 37, 43, 512)  0           ['add_281[0][0]']
#
#  res2conv4x_3_branch2a (Conv2D)  (None, 37, 43, 128)  65664      ['activation_1195[0][0]']
#
#  bn2conv4x_3_branch2a (BatchNor  (None, 37, 43, 128)  148        ['res2conv4x_3_branch2a[0][0]']
#  malization)
#
#  activation_1196 (Activation)   (None, 37, 43, 128)  0           ['bn2conv4x_3_branch2a[0][0]']
#
#  res2conv4x_3_branch2b (Conv2D)  (None, 35, 41, 128)  147584     ['activation_1196[0][0]']
#
#  bn2conv4x_3_branch2b (BatchNor  (None, 35, 41, 128)  140        ['res2conv4x_3_branch2b[0][0]']
#  malization)
#
#  activation_1197 (Activation)   (None, 35, 41, 128)  0           ['bn2conv4x_3_branch2b[0][0]']
#
#  res2conv4x_3_branch2c (Conv2D)  (None, 35, 41, 512)  66048      ['activation_1197[0][0]']
#
#  bn2conv4x_3_branch2c (BatchNor  (None, 35, 41, 512)  140        ['res2conv4x_3_branch2c[0][0]']
#  malization)
#
#  res2conv4x_3_branch2 (Conv2D)  (None, 35, 41, 512)  2359808     ['activation_1195[0][0]']
#
#  activation_1198 (Activation)   (None, 35, 41, 512)  0           ['bn2conv4x_3_branch2c[0][0]']
#
#  bn2conv4x_3_branch2 (BatchNorm  (None, 35, 41, 512)  140        ['res2conv4x_3_branch2[0][0]']
#  alization)
#
#  add_282 (Add)                  (None, 35, 41, 512)  0           ['activation_1198[0][0]',
#                                                                   'bn2conv4x_3_branch2[0][0]']
#
#  activation_1199 (Activation)   (None, 35, 41, 512)  0           ['add_282[0][0]']
#
#  res2conv4x_4_branch2a (Conv2D)  (None, 35, 41, 128)  65664      ['activation_1199[0][0]']
#
#  bn2conv4x_4_branch2a (BatchNor  (None, 35, 41, 128)  140        ['res2conv4x_4_branch2a[0][0]']
#  malization)
#
#  activation_1200 (Activation)   (None, 35, 41, 128)  0           ['bn2conv4x_4_branch2a[0][0]']
#
#  res2conv4x_4_branch2b (Conv2D)  (None, 33, 39, 128)  147584     ['activation_1200[0][0]']
#
#  bn2conv4x_4_branch2b (BatchNor  (None, 33, 39, 128)  132        ['res2conv4x_4_branch2b[0][0]']
#  malization)
#
#  activation_1201 (Activation)   (None, 33, 39, 128)  0           ['bn2conv4x_4_branch2b[0][0]']
#
#  res2conv4x_4_branch2c (Conv2D)  (None, 33, 39, 512)  66048      ['activation_1201[0][0]']
#
#  bn2conv4x_4_branch2c (BatchNor  (None, 33, 39, 512)  132        ['res2conv4x_4_branch2c[0][0]']
#  malization)
#
#  res2conv4x_4_branch2 (Conv2D)  (None, 33, 39, 512)  2359808     ['activation_1199[0][0]']
#
#  activation_1202 (Activation)   (None, 33, 39, 512)  0           ['bn2conv4x_4_branch2c[0][0]']
#
#  bn2conv4x_4_branch2 (BatchNorm  (None, 33, 39, 512)  132        ['res2conv4x_4_branch2[0][0]']
#  alization)
#
#  add_283 (Add)                  (None, 33, 39, 512)  0           ['activation_1202[0][0]',
#                                                                   'bn2conv4x_4_branch2[0][0]']
#
#  activation_1203 (Activation)   (None, 33, 39, 512)  0           ['add_283[0][0]']
#
#  res2conv4x_5_branch2a (Conv2D)  (None, 33, 39, 128)  65664      ['activation_1203[0][0]']
#
#  bn2conv4x_5_branch2a (BatchNor  (None, 33, 39, 128)  132        ['res2conv4x_5_branch2a[0][0]']
#  malization)
#
#  activation_1204 (Activation)   (None, 33, 39, 128)  0           ['bn2conv4x_5_branch2a[0][0]']
#
#  res2conv4x_5_branch2b (Conv2D)  (None, 31, 37, 128)  147584     ['activation_1204[0][0]']
#
#  bn2conv4x_5_branch2b (BatchNor  (None, 31, 37, 128)  124        ['res2conv4x_5_branch2b[0][0]']
#  malization)
#
#  activation_1205 (Activation)   (None, 31, 37, 128)  0           ['bn2conv4x_5_branch2b[0][0]']
#
#  res2conv4x_5_branch2c (Conv2D)  (None, 31, 37, 512)  66048      ['activation_1205[0][0]']
#
#  bn2conv4x_5_branch2c (BatchNor  (None, 31, 37, 512)  124        ['res2conv4x_5_branch2c[0][0]']
#  malization)
#
#  res2conv4x_5_branch2 (Conv2D)  (None, 31, 37, 512)  2359808     ['activation_1203[0][0]']
#
#  activation_1206 (Activation)   (None, 31, 37, 512)  0           ['bn2conv4x_5_branch2c[0][0]']
#
#  bn2conv4x_5_branch2 (BatchNorm  (None, 31, 37, 512)  124        ['res2conv4x_5_branch2[0][0]']
#  alization)
#
#  add_284 (Add)                  (None, 31, 37, 512)  0           ['activation_1206[0][0]',
#                                                                   'bn2conv4x_5_branch2[0][0]']
#
#  activation_1207 (Activation)   (None, 31, 37, 512)  0           ['add_284[0][0]']
#
#  res2conv4x_6_branch2a (Conv2D)  (None, 31, 37, 128)  65664      ['activation_1207[0][0]']
#
#  bn2conv4x_6_branch2a (BatchNor  (None, 31, 37, 128)  124        ['res2conv4x_6_branch2a[0][0]']
#  malization)
#
#  activation_1208 (Activation)   (None, 31, 37, 128)  0           ['bn2conv4x_6_branch2a[0][0]']
#
#  res2conv4x_6_branch2b (Conv2D)  (None, 29, 35, 128)  147584     ['activation_1208[0][0]']
#
#  bn2conv4x_6_branch2b (BatchNor  (None, 29, 35, 128)  116        ['res2conv4x_6_branch2b[0][0]']
#  malization)
#
#  activation_1209 (Activation)   (None, 29, 35, 128)  0           ['bn2conv4x_6_branch2b[0][0]']
#
#  res2conv4x_6_branch2c (Conv2D)  (None, 29, 35, 512)  66048      ['activation_1209[0][0]']
#
#  bn2conv4x_6_branch2c (BatchNor  (None, 29, 35, 512)  116        ['res2conv4x_6_branch2c[0][0]']
#  malization)
#
#  res2conv4x_6_branch2 (Conv2D)  (None, 29, 35, 512)  2359808     ['activation_1207[0][0]']
#
#  activation_1210 (Activation)   (None, 29, 35, 512)  0           ['bn2conv4x_6_branch2c[0][0]']
#
#  bn2conv4x_6_branch2 (BatchNorm  (None, 29, 35, 512)  116        ['res2conv4x_6_branch2[0][0]']
#  alization)
#
#  add_285 (Add)                  (None, 29, 35, 512)  0           ['activation_1210[0][0]',
#                                                                   'bn2conv4x_6_branch2[0][0]']
#
#  activation_1211 (Activation)   (None, 29, 35, 512)  0           ['add_285[0][0]']
#
#  res2conv5x_1_branch2a (Conv2D)  (None, 29, 35, 256)  131328     ['activation_1211[0][0]']
#
#  bn2conv5x_1_branch2a (BatchNor  (None, 29, 35, 256)  116        ['res2conv5x_1_branch2a[0][0]']
#  malization)
#
#  activation_1212 (Activation)   (None, 29, 35, 256)  0           ['bn2conv5x_1_branch2a[0][0]']
#
#  res2conv5x_1_branch2b (Conv2D)  (None, 14, 17, 256)  590080     ['activation_1212[0][0]']
#
#  bn2conv5x_1_branch2b (BatchNor  (None, 14, 17, 256)  56         ['res2conv5x_1_branch2b[0][0]']
#  malization)
#
#  activation_1213 (Activation)   (None, 14, 17, 256)  0           ['bn2conv5x_1_branch2b[0][0]']
#
#  res2conv5x_1_branch2c (Conv2D)  (None, 14, 17, 1024  263168     ['activation_1213[0][0]']
#                                 )
#
#  bn2conv5x_1_branch2c (BatchNor  (None, 14, 17, 1024  56         ['res2conv5x_1_branch2c[0][0]']
#  malization)                    )
#
#  res2conv5x_1_branch2 (Conv2D)  (None, 14, 17, 1024  4719616     ['activation_1211[0][0]']
#                                 )
#
#  activation_1214 (Activation)   (None, 14, 17, 1024  0           ['bn2conv5x_1_branch2c[0][0]']
#                                 )
#
#  bn2conv5x_1_branch2 (BatchNorm  (None, 14, 17, 1024  56         ['res2conv5x_1_branch2[0][0]']
#  alization)                     )
#
#  add_286 (Add)                  (None, 14, 17, 1024  0           ['activation_1214[0][0]',
#                                 )                                 'bn2conv5x_1_branch2[0][0]']
#
#  activation_1215 (Activation)   (None, 14, 17, 1024  0           ['add_286[0][0]']
#                                 )
#
#  res2conv5x_2_branch2a (Conv2D)  (None, 14, 17, 256)  262400     ['activation_1215[0][0]']
#
#  bn2conv5x_2_branch2a (BatchNor  (None, 14, 17, 256)  56         ['res2conv5x_2_branch2a[0][0]']
#  malization)
#
#  activation_1216 (Activation)   (None, 14, 17, 256)  0           ['bn2conv5x_2_branch2a[0][0]']
#
#  res2conv5x_2_branch2b (Conv2D)  (None, 12, 15, 256)  590080     ['activation_1216[0][0]']
#
#  bn2conv5x_2_branch2b (BatchNor  (None, 12, 15, 256)  48         ['res2conv5x_2_branch2b[0][0]']
#  malization)
#
#  activation_1217 (Activation)   (None, 12, 15, 256)  0           ['bn2conv5x_2_branch2b[0][0]']
#
#  res2conv5x_2_branch2c (Conv2D)  (None, 12, 15, 1024  263168     ['activation_1217[0][0]']
#                                 )
#
#  bn2conv5x_2_branch2c (BatchNor  (None, 12, 15, 1024  48         ['res2conv5x_2_branch2c[0][0]']
#  malization)                    )
#
#  res2conv5x_2_branch2 (Conv2D)  (None, 12, 15, 1024  9438208     ['activation_1215[0][0]']
#                                 )
#
#  activation_1218 (Activation)   (None, 12, 15, 1024  0           ['bn2conv5x_2_branch2c[0][0]']
#                                 )
#
#  bn2conv5x_2_branch2 (BatchNorm  (None, 12, 15, 1024  48         ['res2conv5x_2_branch2[0][0]']
#  alization)                     )
#
#  add_287 (Add)                  (None, 12, 15, 1024  0           ['activation_1218[0][0]',
#                                 )                                 'bn2conv5x_2_branch2[0][0]']
#
#  activation_1219 (Activation)   (None, 12, 15, 1024  0           ['add_287[0][0]']
#                                 )
#
#  res2conv5x_3_branch2a (Conv2D)  (None, 12, 15, 256)  262400     ['activation_1219[0][0]']
#
#  bn2conv5x_3_branch2a (BatchNor  (None, 12, 15, 256)  48         ['res2conv5x_3_branch2a[0][0]']
#  malization)
#
#  activation_1220 (Activation)   (None, 12, 15, 256)  0           ['bn2conv5x_3_branch2a[0][0]']
#
#  res2conv5x_3_branch2b (Conv2D)  (None, 10, 13, 256)  590080     ['activation_1220[0][0]']
#
#  bn2conv5x_3_branch2b (BatchNor  (None, 10, 13, 256)  40         ['res2conv5x_3_branch2b[0][0]']
#  malization)
#
#  activation_1221 (Activation)   (None, 10, 13, 256)  0           ['bn2conv5x_3_branch2b[0][0]']
#
#  res2conv5x_3_branch2c (Conv2D)  (None, 10, 13, 1024  263168     ['activation_1221[0][0]']
#                                 )
#
#  bn2conv5x_3_branch2c (BatchNor  (None, 10, 13, 1024  40         ['res2conv5x_3_branch2c[0][0]']
#  malization)                    )
#
#  res2conv5x_3_branch2 (Conv2D)  (None, 10, 13, 1024  9438208     ['activation_1219[0][0]']
#                                 )
#
#  activation_1222 (Activation)   (None, 10, 13, 1024  0           ['bn2conv5x_3_branch2c[0][0]']
#                                 )
#
#  bn2conv5x_3_branch2 (BatchNorm  (None, 10, 13, 1024  40         ['res2conv5x_3_branch2[0][0]']
#  alization)                     )
#
#  add_288 (Add)                  (None, 10, 13, 1024  0           ['activation_1222[0][0]',
#                                 )                                 'bn2conv5x_3_branch2[0][0]']
#
#  activation_1223 (Activation)   (None, 10, 13, 1024  0           ['add_288[0][0]']
#                                 )
#
#  avg_pool (AveragePooling2D)    (None, 5, 6, 1024)   0           ['activation_1223[0][0]']
#
#  flatten_19 (Flatten)           (None, 30720)        0           ['avg_pool[0][0]']
#
#  first_dense (Dense)            (None, 512)          15729152    ['flatten_19[0][0]']
#
#  second_dense (Dense)           (None, 100)          51300       ['first_dense[0][0]']
#
#  fc_outputs (Dense)             (None, 1)            101         ['second_dense[0][0]']
#
# ==================================================================================================
# Total params: 56,653,309
# Trainable params: 56,649,187
# Non-trainable params: 4,122
# __________________________________________________________________________________________________

# %%
# setting an adaptive learning rate

def adapt_learning_rate(epoch):
    if(epoch==1):
        lr = 0.001
    elif(epoch!=1):
        lr = 0.1*epoch
    return lr

lr_history = tk.callbacks.Callback.LearningRate()
lr_rate = tk.callbacks.LearningRateScheduler(adapt_learning_rate)

BATCH_SIZE = 64
EPOCHS = 15
# history = res.fit(x_train, y_train,
#         batch_size=BATCH_SIZE,
#         epochs=EPOCHS,
#         callbacks=[lr_history,lr_rate],
#         validation_data=(x_val, y_val),
#         shuffle=True)

# %%
def f(n,k,s):
    n_out = (n-k)/s + 1
    return n_out
f(26,25,1)
# Out:
# 2.0

# %%
def conv1(X, block="conv1", stage=2):
            
        # defining name basis
        conv_name_base = 'res' + str(stage) + block + '_branch'
        bn_name_base = 'bn' + str(stage) + block + '_branch'
        
        X_input = X
        # First component of main path
        X = Conv2D(64, kernel_size = (6,3), strides = (2,1),
                name = conv_name_base + '2a',
                #nchannels??
                # data_format="channels_first", 
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)
        X = BatchNormalization(axis = 1, name = bn_name_base + '2a')(X)
        X = Activation('relu')(X)
        
        # Second component of main path
        X = Conv2D(64, kernel_size = (3,3), strides = (2,2),
                name = conv_name_base + '2b',
                #nchannels?? 
                # kernel_initializer = glorot_uniform(seed=0)
                )(X)
        X = BatchNormalization(axis=1, name = bn_name_base + '2b')(X)
        X = Activation('relu')(X)

        X = MaxPooling2D((2,2), strides=(1,1))(X)
        
        # Create model
        model = Model(inputs = X_input, outputs = X, name = 'ResNetJ')
        
        # Compile model
        learning_rate = 1e-3
        opt = tk.optimizers.Adam(learning_rate=learning_rate, beta_1 = 0.9, beta_2 = 0.999 )

        model.compile(loss="mean_squared_error", optimizer=opt, metrics=['accuracy'])
        
        return model

# %%
X_input = Input(shape=(230,124,2))
res1 = conv1(X_input)
res1.summary()
# Out:
# Model: "ResNetJ"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 230, 124, 2)]     0
#
#  res2conv1_branch2a (Conv2D)  (None, 113, 122, 64)     2368
#
#  bn2conv1_branch2a (BatchNor  (None, 113, 122, 64)     452
#  malization)
#
#  activation_230 (Activation)  (None, 113, 122, 64)     0
#
#  res2conv1_branch2b (Conv2D)  (None, 56, 60, 64)       36928
#
#  bn2conv1_branch2b (BatchNor  (None, 56, 60, 64)       224
#  malization)
#
#  activation_231 (Activation)  (None, 56, 60, 64)       0
#
#  max_pooling2d_9 (MaxPooling  (None, 55, 59, 64)       0
#  2D)
#
# =================================================================
# Total params: 39,972
# Trainable params: 39,634
# Non-trainable params: 338
# _________________________________________________________________

# %%
    # """
    # prova
    # """
    # # Stage 1
    # X = conv1(X_input, block="conv1")
    # # Stage2
    # X = conv2x(X, stride=1, filters=[64,256], block="conv2x_1")
    # X = conv2x(X, stride=1, filters=[64,256], block="conv2x_2")
    # X = conv2x(X, stride=1, filters=[64,256], block="conv2x_3")

    # # Stage 3
    # X = conv2x(X, stride=1, filters=[64,256], block="conv3x_1")
    # X = conv2x(X, stride=1, filters=[128,512], block="conv3x_2")
    # X = conv2x(X, stride=1, filters=[128,512], block="conv3x_3")
    # X = conv2x(X, stride=1, filters=[128,512], block="conv3x_4")

    # # Stage 4 
    # X = conv2x(X, stride=1, filters=[128,512], block="conv4x_1")
    # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_2")
    # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_3")
    # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_4")
    # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_5")
    # X = conv2x(X, stride=1, filters=[256,1024], block="conv4x_6")

    # # Stage 5
    # X = conv2x(X, stride=1, filters=[512,2048], block="conv5x_1")
    # X = conv2x(X, stride=1, filters=[512,2048], block="conv5x_2")
    # X = conv2x(X, stride=1, filters=[512,2048], block="conv5x_3")
# Out:
# 21.0
